# %%
MinimalDegree := function(grp)
  local ccRep;
  ccRep:=List(ConjugacyClasses(grp), Representative);
 return Minimum(Filtered(List(ccRep, NrMovedPoints), n -> n>0));
end;
# Out:
# function( grp ) ... end

# %%
G:=PGL(2,5);
# Out:
# Group([ (3,6,5,4), (1,2,5)(3,4,6) ])

# %%
MinimalDegree(AGL(3,2));

# %%
LoadPackage("CHEVIE");
# Out:
# #I  chevie package is not available. Check that the name is correct
# #I  and it is present in one of the GAP root directories (see '??RootPaths')
# fail

# %%
# Out:
# Error, Variable: 'CoxeterGroup' must have a value
# not in any function at stream:1

# %%
ActionOnAllProjPoints( G );

# %%
?weyl
# Out:
# Reference: <a target="_blank" href="https://www.gap-system.org/Manuals/doc/ref/chap64.html#X86BED5098322EBEF">WeylGroup</a><br/>Reference: <a target="_blank" href="https://www.gap-system.org/Manuals/doc/ref/chap64.html#X7E000FA97949BFD5">WeylOrbitIterator</a><br/>CTblLib: <a target="_blank" href="https://www.gap-system.org/Manuals/pkg/ctbllib-1.3.1/doc/chap4.html#X81E3F9A384365282">Weyl groups!character table</a><br/>QuaGroup (not loaded): <a target="_blank" href="https://www.gap-system.org/Manuals/pkg/quagroup-1.8.2/doc/chap3.html#X798CE6777FC473DD">Weyl groups and their elements</a><br/>QuaGroup (not loaded): <a target="_blank" href="https://www.gap-system.org/Manuals/pkg/quagroup-1.8.2/doc/chap3.html#X8573A4077DB4659F">WeylWord</a><br/>SLA (not loaded): <a target="_blank" href="https://www.gap-system.org/Manuals/pkg/sla-1.5.3/doc/chap2.html#X808290B47CC22D62">Weyl groups</a><br/>SLA (not loaded): <a target="_blank" href="https://www.gap-system.org/Manuals/pkg/sla-1.5.3/doc/chap2.h
# ...
